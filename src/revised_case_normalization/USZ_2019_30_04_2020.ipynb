# %% [markdown]
# # Revised case normalization for USZ 2019 (30.04.2020)
#
# Notes:
# -

# %%
import pandas as pd
import sys
sys.path.insert(0, '/home/jovyan/work')

import os

from py.global_configs import *
from py.normalize import normalize

from src.service import bfs_cases_db_service as bfs_db

from src.utils.dataframe_utils import remove_duplicated_chops
# Out:
# /home/jovyan/work/src/models/BfsCase.py:5: SAWarning: On class 'BfsCase', Column object 'drg_cost_weight' named directly multiple times, only one will be used: drg_cost_weight, effective_cost_weight. Consider using orm.synonym instead
#   class BfsCase(Base):

# %%
file_info = FileInfo(
         os.path.join(ROOT_DIR, 'raw_data/USZ_2018-2019_20200730.xlsx'),
         'USZ',
         '2019-2020',
         ['Rückmeldung_USZ_2019_30.04.2020'])

print(file_info)
# Out:
# FileInfo(path='/home/jovyan/work/src/revised_case_normalization/raw_data/USZ_2018-2019_20200730.xlsx', hospital_name_db='USZ', year='2019-2020', sheets=['Rückmeldung_USZ_2019_30.04.2020'])

# %%
cols_to_rename = dict(COLUMNS_TO_RENAME)
# Replace 'admno' with 'fall nummer'
cols_to_rename.pop('admno')
cols_to_rename['fall nummer'] = CASE_ID_COL

df_revised_case_d2d = normalize(file_info, 0)
# Out:
# 2022-10-17 14:41:45.838 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 5: discarded ICDs after validation {'E1191.N133'}
# 2022-10-17 14:41:45.838 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 6: discarded ICDs after validation {'R18.K746.I982'}
# 2022-10-17 14:41:45.839 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 7: discarded ICDs after validation {'I690.Z930'}
# 2022-10-17 14:41:45.839 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 10: discarded ICDs after validation {'G8209.R471'}
# Read 154 cases for USZ 2019-2020
# TYPES:
# case_id             string
# patient_id          string
# gender              string
# age_years            int64
# duration_of_stay     int64
# pccl                 int64
# drg                 string
# old_pd              string
# new_pd              string
# bfs_code            string
# added_icds          string
# removed_icds        string
# added_chops         string
# removed_chops       string
# dtype: object
# 2022-10-17 14:41:45.840 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 12: discarded ICDs after validation {'E1141.G632'}
# 2022-10-17 14:41:45.843 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 91: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.844 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 99: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.846 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 115: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.847 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 122: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.847 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 127: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.848 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 141: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.849 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 143: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.852 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 0: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.853 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 1: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.853 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 2: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.854 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 3: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.855 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 4: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.855 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 6: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.856 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 7: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.856 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 8: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.857 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 10: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.858 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 11: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.858 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 13: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.859 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 14: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.860 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 15: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.860 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 16: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.861 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 18: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.862 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 19: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.863 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 20: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.863 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 21: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.864 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 22: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.865 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 23: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.865 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 24: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.866 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 25: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.867 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 26: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.868 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 27: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.869 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 29: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.869 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 30: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.869 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 31: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.870 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 33: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.871 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 35: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.872 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 36: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.872 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 37: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.873 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 38: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.874 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 39: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.875 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 40: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.875 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 41: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.875 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 42: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.876 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 43: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.877 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 44: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.878 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 45: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.879 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 47: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.879 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 48: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.880 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 49: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.881 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 52: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.882 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 53: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.883 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 54: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.883 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 55: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.884 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 57: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.885 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 59: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.886 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 60: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.887 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 61: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.887 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 64: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.888 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 65: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.889 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 70: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.889 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 71: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.890 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 75: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.891 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 76: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.891 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 77: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.891 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 79: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.892 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 82: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.893 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 83: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.893 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 84: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.894 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 85: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.895 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 86: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.896 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 87: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.896 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 89: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.897 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 91: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.898 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 94: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.898 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 95: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.899 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 97: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.899 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 98: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.900 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 99: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.901 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 101: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.902 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 102: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.902 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 103: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.903 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 105: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.903 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 107: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.904 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 108: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.904 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 109: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.905 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 111: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.906 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 112: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.906 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 113: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.907 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 114: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.908 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 115: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.908 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 116: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.909 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 117: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.910 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 118: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.911 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 122: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.912 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 123: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.912 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 125: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.913 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 126: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.914 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 127: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.914 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 128: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.915 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 130: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.915 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 131: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.916 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 135: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.917 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 136: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.917 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 137: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.918 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 138: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.919 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 139: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.919 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 140: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.920 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 141: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.920 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 142: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.921 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 143: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.922 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 144: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.922 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 145: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.923 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 147: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.924 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 148: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.924 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 149: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.924 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 150: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.925 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 151: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.926 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 152: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.926 | DEBUG    | src.utils.dataframe_utils:_validate_icd_codes:56 - row 153: discarded ICDs after validation {''}
# 2022-10-17 14:41:45.929 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 0: discarded duplicated and invalid CHOP entries after validation {'99b813::20181227', '009a13:L:20181231', '948x41::20190108'}
# 2022-10-17 14:41:45.930 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 1: discarded duplicated and invalid CHOP entries after validation {'890a11::20190211'}
# 2022-10-17 14:41:45.931 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 2: discarded duplicated and invalid CHOP entries after validation {'948x41::20190607', '99c121::20190607'}
# 2022-10-17 14:41:45.932 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 3: discarded duplicated and invalid CHOP entries after validation {'99c11d::20190708', '948x41::20190709'}
# 2022-10-17 14:41:45.932 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 4: discarded duplicated and invalid CHOP entries after validation {'890a21::20190115'}
# 2022-10-17 14:41:45.933 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 5: discarded duplicated and invalid CHOP entries after validation {'7a4212::20190125.890a21::20190124.7ab2::20190125.7ab131::20190125.7aa413::20190125'}
# 2022-10-17 14:41:45.933 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 6: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.933 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 7: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.934 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 8: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.935 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 9: discarded duplicated and invalid CHOP entries after validation {'890a19::20190110.890a32::20181220'}
# 2022-10-17 14:41:45.935 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 10: discarded duplicated and invalid CHOP entries after validation {'99c123::20190625.948x30::20190626.948x41::20190626'}
# 2022-10-17 14:41:45.936 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 11: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.937 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 12: discarded duplicated and invalid CHOP entries after validation {'890a11::20190829.560x99:R:20190902.99c121::20190906'}
# 2022-10-17 14:41:45.937 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 13: discarded duplicated and invalid CHOP entries after validation {'009b11::20191121'}
# 2022-10-17 14:41:45.938 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 14: discarded duplicated and invalid CHOP entries after validation {'866b21:R:20191112', '890a12::20191112'}
# 2022-10-17 14:41:45.939 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 15: discarded duplicated and invalid CHOP entries after validation {'009a13::20191114', '99c124::20191126', '623x40:L:20191114', '867c18::20191114'}
# 2022-10-17 14:41:45.939 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 16: discarded duplicated and invalid CHOP entries after validation {'99b811::20191023'}
# 2022-10-17 14:41:45.940 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 17: discarded duplicated and invalid CHOP entries after validation {'99a7::20191107'}
# 2022-10-17 14:41:45.940 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 18: discarded duplicated and invalid CHOP entries after validation {'004b18:R:20191111', '004b44:R:20191111', '890a21::20191111', '004b17:R:20191111'}
# 2022-10-17 14:41:45.941 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 19: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.941 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 20: discarded duplicated and invalid CHOP entries after validation {'948x10::20191129'}
# 2022-10-17 14:41:45.942 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 21: discarded duplicated and invalid CHOP entries after validation {'99c11d::20191117', '890a32::20191104', '948x41::20191118'}
# 2022-10-17 14:41:45.942 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 22: discarded duplicated and invalid CHOP entries after validation {'86531e:L:20191129', '8688i1:L:20191120', '8688i1:L:20191116', '8688i1:L:20191118', '8688i5:L:20191129', '8688i1:L:20191123', '8688i1:L:20191126', '890a13::20191116'}
# 2022-10-17 14:41:45.943 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 23: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.943 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 24: discarded duplicated and invalid CHOP entries after validation {'890a32::20191218'}
# 2022-10-17 14:41:45.944 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 25: discarded duplicated and invalid CHOP entries after validation {'3995b1::20191113', '009a26::20191112'}
# 2022-10-17 14:41:45.945 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 26: discarded duplicated and invalid CHOP entries after validation {'399a11:R:20191217'}
# 2022-10-17 14:41:45.945 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 27: discarded duplicated and invalid CHOP entries after validation {'948x41::20191122', '544x99::20191111', '544x12::20191111', '99b712::20191111'}
# 2022-10-17 14:41:45.946 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 28: discarded duplicated and invalid CHOP entries after validation {'560x99::20191204'}
# 2022-10-17 14:41:45.947 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 29: discarded duplicated and invalid CHOP entries after validation {'948x40::20191119', '009a10::20191114'}
# 2022-10-17 14:41:45.947 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 30: discarded duplicated and invalid CHOP entries after validation {'403x23:R:20191029', '99b712::20191029', '009a13::20191029', '99b811::20191030'}
# 2022-10-17 14:41:45.948 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 31: discarded duplicated and invalid CHOP entries after validation {'8688j3::20191220', '890a12::20191220', '8688i5::20191215', '8688j3::20191218', '862a3e::20191215'}
# 2022-10-17 14:41:45.948 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 32: discarded duplicated and invalid CHOP entries after validation {'99c121::20191125', '99b812::20191116'}
# 2022-10-17 14:41:45.949 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 33: discarded duplicated and invalid CHOP entries after validation {'99c121::20191217', '009a12::20191209', '99b813::20191209'}
# 2022-10-17 14:41:45.950 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 34: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.950 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 35: discarded duplicated and invalid CHOP entries after validation {'948x42::20191212'}
# 2022-10-17 14:41:45.951 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 36: discarded duplicated and invalid CHOP entries after validation {'99b811::20191125', '346x23:R:20191125'}
# 2022-10-17 14:41:45.952 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 37: discarded duplicated and invalid CHOP entries after validation {'948x41::20191216', '54a1::20191205', '99c121::20191213', '890a32::20191209'}
# 2022-10-17 14:41:45.953 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 38: discarded duplicated and invalid CHOP entries after validation {'890a22::20191203'}
# 2022-10-17 14:41:45.954 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 39: discarded duplicated and invalid CHOP entries after validation {'948x41::20191218', '99b713::20191211'}
# 2022-10-17 14:41:45.954 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 40: discarded duplicated and invalid CHOP entries after validation {'99b811::20191205'}
# 2022-10-17 14:41:45.955 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 41: discarded duplicated and invalid CHOP entries after validation {'99c122::20191201', '890a21::20191202', '948x20::20191202'}
# 2022-10-17 14:41:45.955 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 42: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.956 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 43: discarded duplicated and invalid CHOP entries after validation {'99c121::20191120', '99b811::20191104', '948x41::20191120'}
# 2022-10-17 14:41:45.957 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 44: discarded duplicated and invalid CHOP entries after validation {'99b711::20191125', '890a21::20191121', '004b17:R:20191125'}
# 2022-10-17 14:41:45.957 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 45: discarded duplicated and invalid CHOP entries after validation {'890a11::20191126', '890a21::20191203', '890a32::20191203'}
# 2022-10-17 14:41:45.958 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 46: discarded duplicated and invalid CHOP entries after validation {'99b713::20191203', '939b::20191203', '361c14::20191203', '890a21::20191203', '361d11::20191203'}
# 2022-10-17 14:41:45.958 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 47: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.959 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 48: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.960 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 49: discarded duplicated and invalid CHOP entries after validation {'948x41::20191120'}
# 2022-10-17 14:41:45.960 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 50: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.961 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 51: discarded duplicated and invalid CHOP entries after validation {'99c11d::20191226'}
# 2022-10-17 14:41:45.961 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 52: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.962 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 53: discarded duplicated and invalid CHOP entries after validation {'99c124::20191129'}
# 2022-10-17 14:41:45.962 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 54: discarded duplicated and invalid CHOP entries after validation {'99c122::20191210', '948x30::20191211', '890a21::20191209'}
# 2022-10-17 14:41:45.963 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 55: discarded duplicated and invalid CHOP entries after validation {'890a21::20191024', '570x99::20191030', '948x40::20191028'}
# 2022-10-17 14:41:45.964 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 56: discarded duplicated and invalid CHOP entries after validation {'99b711::20191031'}
# 2022-10-17 14:41:45.965 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 57: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.965 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 58: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.965 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 59: discarded duplicated and invalid CHOP entries after validation {'890a11::20191108', '948x41::20191119', '99c11d::20191111', '403x23:B:20191030', '598x10:B:20191030'}
# 2022-10-17 14:41:45.966 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 60: discarded duplicated and invalid CHOP entries after validation {'890a32::20191213', '544x12::20191206', '009a22::20191213'}
# 2022-10-17 14:41:45.966 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 61: discarded duplicated and invalid CHOP entries after validation {'3995b1::20191216', '3995b1::20191220'}
# 2022-10-17 14:41:45.967 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 62: discarded duplicated and invalid CHOP entries after validation {'99c11d::20191223', '938a35::20191228', '948x41::20191224'}
# 2022-10-17 14:41:45.967 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 63: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.968 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 64: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.969 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 65: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.969 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 66: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.971 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 67: discarded duplicated and invalid CHOP entries after validation {'004b18:R:20181228', '004b1a:R:20181227', '004b18:R:20181227', '99b812::20181227', '948x41:R:20190108', '004c11:R:20181227'}
# 2022-10-17 14:41:45.971 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 68: discarded duplicated and invalid CHOP entries after validation {'948x41::20190219', '890a21::20190219', '890a11::20190206'}
# 2022-10-17 14:41:45.972 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 69: discarded duplicated and invalid CHOP entries after validation {'361d11::20190107', '361c14::20190107', '890a21::20190111', '939b::20190107', '99b712::20190107'}
# 2022-10-17 14:41:45.972 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 70: discarded duplicated and invalid CHOP entries after validation {'948x41::20190214', '378a41::20190211', '99b811::20190205'}
# 2022-10-17 14:41:45.973 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 71: discarded duplicated and invalid CHOP entries after validation {'948x40::20190116', '890a21::20190111'}
# 2022-10-17 14:41:45.973 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 72: discarded duplicated and invalid CHOP entries after validation {'99b812::20190409', '890a21::20190415', '948x41::20190417'}
# 2022-10-17 14:41:45.974 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 73: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.974 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 74: discarded duplicated and invalid CHOP entries after validation {'890a21::20190206', '99b712::20190206', '948x41::20190218', '99b811::20190207'}
# 2022-10-17 14:41:45.975 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 75: discarded duplicated and invalid CHOP entries after validation {'99b811::20190424'}
# 2022-10-17 14:41:45.975 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 76: discarded duplicated and invalid CHOP entries after validation {'99b810::20191002'}
# 2022-10-17 14:41:45.976 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 77: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.977 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 78: discarded duplicated and invalid CHOP entries after validation {'948x40::20190201'}
# 2022-10-17 14:41:45.977 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 79: discarded duplicated and invalid CHOP entries after validation {'99c125::20191018', '890a12::20191021', '890a21::20191016', '890a32::20191018', '99b712::20191015', '948x41::20191030', '99b811::20191017'}
# 2022-10-17 14:41:45.978 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 80: discarded duplicated and invalid CHOP entries after validation {'866a1c:L:20191023', '86311e:R:20191023', '862b2e:B:20191019', '862a1e:L:20191023'}
# 2022-10-17 14:41:45.979 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 81: discarded duplicated and invalid CHOP entries after validation {'93a309::20190208'}
# 2022-10-17 14:41:45.979 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 82: discarded duplicated and invalid CHOP entries after validation {'890a21::20191120', '948x42::20191121'}
# 2022-10-17 14:41:45.980 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 83: discarded duplicated and invalid CHOP entries after validation {'890a21::20190416'}
# 2022-10-17 14:41:45.980 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 84: discarded duplicated and invalid CHOP entries after validation {'890a21::20191210', '99c11d::20191211'}
# 2022-10-17 14:41:45.981 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 85: discarded duplicated and invalid CHOP entries after validation {'99c123::20191112', '890a32::20191021', '890a21::20191022', '99b811::20191017'}
# 2022-10-17 14:41:45.982 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 86: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.983 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 87: discarded duplicated and invalid CHOP entries after validation {'890a21::20190402'}
# 2022-10-17 14:41:45.983 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 88: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.984 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 89: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.984 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 90: discarded duplicated and invalid CHOP entries after validation {'99b811::20190923', '948x41::20190930', '004f11:L:20190922', '99ba14::20190922'}
# 2022-10-17 14:41:45.985 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 91: discarded duplicated and invalid CHOP entries after validation {'004b1a:R:20191024', '004b18::20191024'}
# 2022-10-17 14:41:45.986 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 92: discarded duplicated and invalid CHOP entries after validation {'890a11::20190702', '948x41::20190710', '99c11d::20190706'}
# 2022-10-17 14:41:45.986 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 93: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.987 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 94: discarded duplicated and invalid CHOP entries after validation {'890a21::20190718', '890a11::20190729'}
# 2022-10-17 14:41:45.987 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 96: discarded duplicated and invalid CHOP entries after validation {'948x42::20191022'}
# 2022-10-17 14:41:45.987 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 97: discarded duplicated and invalid CHOP entries after validation {'948x41::20190710'}
# 2022-10-17 14:41:45.988 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 98: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.989 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 99: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.989 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 100: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.990 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 101: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.991 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 102: discarded duplicated and invalid CHOP entries after validation {'99b810::20190810', '948x41::20190822', '99c122::20190822', '948x31::20190823'}
# 2022-10-17 14:41:45.991 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 103: discarded duplicated and invalid CHOP entries after validation {'890a21::20190528'}
# 2022-10-17 14:41:45.992 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 104: discarded duplicated and invalid CHOP entries after validation {'99072c::20190407', '890a21::20190410'}
# 2022-10-17 14:41:45.992 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 105: discarded duplicated and invalid CHOP entries after validation {'890a32::20190128', '866b25:L:20190128', '948x41::20190213'}
# 2022-10-17 14:41:45.993 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 106: discarded duplicated and invalid CHOP entries after validation {'890a32::20181231'}
# 2022-10-17 14:41:45.993 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 107: discarded duplicated and invalid CHOP entries after validation {'99b813::20190417', '99ba41::20190414', '948x41::20190426', '99b713::20190414'}
# 2022-10-17 14:41:45.994 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 108: discarded duplicated and invalid CHOP entries after validation {'009a14:R:20190424', '99b811::20190424'}
# 2022-10-17 14:41:45.994 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 109: discarded duplicated and invalid CHOP entries after validation {'890a32::20190510', '99b811::20190429', '939b::20190510', '99b714::20190510', '99c122::20190515', '948x30::20190515'}
# 2022-10-17 14:41:45.995 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 110: discarded duplicated and invalid CHOP entries after validation {'890a13::20190310'}
# 2022-10-17 14:41:45.996 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 111: discarded duplicated and invalid CHOP entries after validation {'890a12::20190513', '948x41::20190517'}
# 2022-10-17 14:41:45.996 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 112: discarded duplicated and invalid CHOP entries after validation {'948x41::20190507', '502a2c::20190430', '890a21::20190502', '99b811::20190430'}
# 2022-10-17 14:41:45.997 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 113: discarded duplicated and invalid CHOP entries after validation {'890a11::20190417'}
# 2022-10-17 14:41:45.998 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 114: discarded duplicated and invalid CHOP entries after validation {'99b812::20190609'}
# 2022-10-17 14:41:45.999 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 115: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:45.999 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 116: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.000 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 117: discarded duplicated and invalid CHOP entries after validation {'938a35::20191003', '99c126::20191002', '948x41::20191003'}
# 2022-10-17 14:41:46.000 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 118: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.000 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 119: discarded duplicated and invalid CHOP entries after validation {'890a21::20190723'}
# 2022-10-17 14:41:46.001 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 120: discarded duplicated and invalid CHOP entries after validation {'890a21::20191125'}
# 2022-10-17 14:41:46.002 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 121: discarded duplicated and invalid CHOP entries after validation {'99b711::20190904', '948x41::20190906'}
# 2022-10-17 14:41:46.002 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 122: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.003 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 123: discarded duplicated and invalid CHOP entries after validation {'948x20::20190722', '890a21::20190715', '948x40::20190722'}
# 2022-10-17 14:41:46.004 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 124: discarded duplicated and invalid CHOP entries after validation {'99c127::20190916'}
# 2022-10-17 14:41:46.004 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 125: discarded duplicated and invalid CHOP entries after validation {'890a11::20190913'}
# 2022-10-17 14:41:46.005 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 126: discarded duplicated and invalid CHOP entries after validation {'948x21::20190925'}
# 2022-10-17 14:41:46.005 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 127: discarded duplicated and invalid CHOP entries after validation {'890a11::20191003'}
# 2022-10-17 14:41:46.006 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 128: discarded duplicated and invalid CHOP entries after validation {'99c12c::20191114', '93a309::20191106', '948x42::20191126'}
# 2022-10-17 14:41:46.006 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 129: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.007 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 130: discarded duplicated and invalid CHOP entries after validation {'598x10:B:20190320', '99c123::20190331', '99b812::20190321'}
# 2022-10-17 14:41:46.008 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 131: discarded duplicated and invalid CHOP entries after validation {'3995b1::20190515', '99b812::20190515'}
# 2022-10-17 14:41:46.009 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 132: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.009 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 133: discarded duplicated and invalid CHOP entries after validation {'8688i5::20190319', '862a2e:L:20190319', '948x42::20190329', '9389a1::20190326', '866a2c:L:20190319'}
# 2022-10-17 14:41:46.011 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 134: discarded duplicated and invalid CHOP entries after validation {'7ab131::20190116', '948x42::20190116', '7a4411::20190116'}
# 2022-10-17 14:41:46.011 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 135: discarded duplicated and invalid CHOP entries after validation {'5185::20190610'}
# 2022-10-17 14:41:46.012 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 136: discarded duplicated and invalid CHOP entries after validation {'99b812::20191018'}
# 2022-10-17 14:41:46.012 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 137: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.013 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 138: discarded duplicated and invalid CHOP entries after validation {'009a13::20190821', '99b811::20190821', '948x41::20190823'}
# 2022-10-17 14:41:46.014 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 139: discarded duplicated and invalid CHOP entries after validation {'99c125::20190715', '99b812::20190627', '009a14::20190627', '009a14:L:20190702', '948x41::20190715'}
# 2022-10-17 14:41:46.014 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 140: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.015 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 141: discarded duplicated and invalid CHOP entries after validation {'890a21::20190528'}
# 2022-10-17 14:41:46.015 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 142: discarded duplicated and invalid CHOP entries after validation {'99b811::20190606', '403x16:L:20190606', '009b11::20190606', '948x41::20190614'}
# 2022-10-17 14:41:46.016 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 143: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.017 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 144: discarded duplicated and invalid CHOP entries after validation {'598x11:L:20190508', '890a12::20190503'}
# 2022-10-17 14:41:46.017 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 145: discarded duplicated and invalid CHOP entries after validation {'86431a::20190528', '890a32::20190522', '99c121::20190603', '8688i6::20190522', '890a12::20190603', '890a21::20190522'}
# 2022-10-17 14:41:46.017 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 146: discarded duplicated and invalid CHOP entries after validation {'890a32::20190603', '252x44:L:20190604', '948x41::20190620', '99c128::20190606', '99b712::20190604'}
# 2022-10-17 14:41:46.019 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 147: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.019 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 148: discarded duplicated and invalid CHOP entries after validation {'186x20:L:20191028', '890a12::20191031', '186x10:L:20191028'}
# 2022-10-17 14:41:46.020 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 149: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.021 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 150: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.021 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 151: discarded duplicated and invalid CHOP entries after validation {'99b713::20190927', '99b812::20191001', '948x41::20191011'}
# 2022-10-17 14:41:46.022 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 152: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.022 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 153: discarded duplicated and invalid CHOP entries after validation {'99b713::20190912', '8688j3::20190916', '99c124::20191001', '99b813::20190912', '009a14:L:20190912', '948x41::20191003'}
# 2022-10-17 14:41:46.025 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 0: discarded duplicated and invalid CHOP entries after validation {'99B813::20181227', '009A13:L:20181231', '948X41::20190108'}
# ...
# 2022-10-17 14:41:46.082 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 92: discarded duplicated and invalid CHOP entries after validation {'948X41::20190710', '99C11D::20190706', '890A11::20190702'}
# 2022-10-17 14:41:46.082 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 93: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.083 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 94: discarded duplicated and invalid CHOP entries after validation {'890A21::20190718', '890A11::20190729'}
# 2022-10-17 14:41:46.084 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 95: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.085 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 96: discarded duplicated and invalid CHOP entries after validation {'922414::20191002', '992811::20191017', '922414::20191001', '922414::20190925', '992811::20191024', '922414::20190930', '948X42::20191022', '922414::20190927', '922414::20190924', '922414::20191003'}
# 2022-10-17 14:41:46.085 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 97: discarded duplicated and invalid CHOP entries after validation {'948X41::20190710'}
# 2022-10-17 14:41:46.086 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 98: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.086 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 99: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.087 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 100: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.087 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 101: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.088 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 102: discarded duplicated and invalid CHOP entries after validation {'99B810::20190810', '99C122::20190822', '948X41::20190822', '948X31::20190823'}
# 2022-10-17 14:41:46.088 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 103: discarded duplicated and invalid CHOP entries after validation {'890A21::20190528'}
# 2022-10-17 14:41:46.089 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 104: discarded duplicated and invalid CHOP entries after validation {'997113::20190409', '99072C::20190407', '997113::20190411', '890A21::20190410'}
# 2022-10-17 14:41:46.089 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 105: discarded duplicated and invalid CHOP entries after validation {'866B25:L:20190128', '8993::20190206', '948X41::20190213', '890A32::20190128'}
# 2022-10-17 14:41:46.090 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 106: discarded duplicated and invalid CHOP entries after validation {'922414::20190104', '922414::20181231', '922414::20190108', '922414::20190103', '922414::20190107', '922414::20190109'}
# 2022-10-17 14:41:46.091 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 107: discarded duplicated and invalid CHOP entries after validation {'99BA41::20190414', '99B813::20190417', '99B713::20190414', '948X41::20190426'}
# 2022-10-17 14:41:46.092 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 108: discarded duplicated and invalid CHOP entries after validation {'009A14:R:20190424', '99B811::20190424'}
# 2022-10-17 14:41:46.092 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 109: discarded duplicated and invalid CHOP entries after validation {'8703::20190507', '8703::20190509', '8703::20190429', '99B811::20190429', '939B::20190510', '99B714::20190510', '891499::20190513', '891499::20190512', '889110::20190424', '891499::20190425', '8993::20190506', '948X30::20190515', '890A32::20190510', '99C122::20190515'}
# 2022-10-17 14:41:46.093 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 110: discarded duplicated and invalid CHOP entries after validation {'890A13::20190310'}
# 2022-10-17 14:41:46.094 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 111: discarded duplicated and invalid CHOP entries after validation {'890A12::20190513', '948X41::20190517'}
# 2022-10-17 14:41:46.094 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 112: discarded duplicated and invalid CHOP entries after validation {'502A2C::20190430', '99B811::20190430', '890A21::20190502', '948X41::20190507'}
# 2022-10-17 14:41:46.095 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 113: discarded duplicated and invalid CHOP entries after validation {'890A11::20190417'}
# 2022-10-17 14:41:46.095 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 114: discarded duplicated and invalid CHOP entries after validation {'99B812::20190609'}
# 2022-10-17 14:41:46.096 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 115: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.096 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 116: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.097 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 117: discarded duplicated and invalid CHOP entries after validation {'99C126::20191002', '880110::20190915', '880110::20190905', '938A35::20191003', '948X41::20191003'}
# 2022-10-17 14:41:46.098 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 118: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.099 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 119: discarded duplicated and invalid CHOP entries after validation {'890A21::20190723'}
# 2022-10-17 14:41:46.099 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 120: discarded duplicated and invalid CHOP entries after validation {'890A21::20191125'}
# 2022-10-17 14:41:46.100 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 121: discarded duplicated and invalid CHOP entries after validation {'99B711::20190904', '948X41::20190906'}
# 2022-10-17 14:41:46.100 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 122: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.101 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 123: discarded duplicated and invalid CHOP entries after validation {'948X40::20190722', '948X20::20190722', '890A21::20190715'}
# 2022-10-17 14:41:46.102 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 124: discarded duplicated and invalid CHOP entries after validation {'99C127::20190916'}
# 2022-10-17 14:41:46.102 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 125: discarded duplicated and invalid CHOP entries after validation {'890A11::20190913'}
# 2022-10-17 14:41:46.103 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 126: discarded duplicated and invalid CHOP entries after validation {'948X21::20190925'}
# 2022-10-17 14:41:46.104 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 127: discarded duplicated and invalid CHOP entries after validation {'890A11::20191003'}
# 2022-10-17 14:41:46.104 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 128: discarded duplicated and invalid CHOP entries after validation {'93A309::20191106', '99C12C::20191114', '948X42::20191126'}
# 2022-10-17 14:41:46.105 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 129: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.106 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 130: discarded duplicated and invalid CHOP entries after validation {'598X10:B:20190320', '99B812::20190321', '99C123::20190331'}
# 2022-10-17 14:41:46.106 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 131: discarded duplicated and invalid CHOP entries after validation {'99B812::20190515', '399521::20190518', '3995B1::20190515'}
# 2022-10-17 14:41:46.107 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 132: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.108 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 133: discarded duplicated and invalid CHOP entries after validation {'948X42::20190329', '862A2E:L:20190319', '9389A1::20190326', '866A2C:L:20190319', '8688I5::20190319'}
# 2022-10-17 14:41:46.108 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 134: discarded duplicated and invalid CHOP entries after validation {'948X42::20190116', '7AB131::20190116', '7A4411::20190116'}
# 2022-10-17 14:41:46.109 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 135: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.110 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 136: discarded duplicated and invalid CHOP entries after validation {'99B812::20191018'}
# 2022-10-17 14:41:46.110 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 137: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.111 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 138: discarded duplicated and invalid CHOP entries after validation {'99B811::20190821', '948X41::20190823', '009A13::20190821'}
# 2022-10-17 14:41:46.112 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 139: discarded duplicated and invalid CHOP entries after validation {'009A14::20190627', '009A14:L:20190702', '948X41::20190715', '99C125::20190715', '99B812::20190627'}
# 2022-10-17 14:41:46.112 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 140: discarded duplicated and invalid CHOP entries after validation {'992551::20190705', '992551::20190711', '3491:L:20190704', '992551::20190708'}
# 2022-10-17 14:41:46.113 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 141: discarded duplicated and invalid CHOP entries after validation {'890A21::20190528'}
# 2022-10-17 14:41:46.113 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 142: discarded duplicated and invalid CHOP entries after validation {'403X16:L:20190606', '99B811::20190606', '948X41::20190614', '009B11::20190606'}
# 2022-10-17 14:41:46.114 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 143: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.114 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 144: discarded duplicated and invalid CHOP entries after validation {'890A12::20190503', '598X11:L:20190508'}
# 2022-10-17 14:41:46.115 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 145: discarded duplicated and invalid CHOP entries after validation {'890A21::20190522', '8688I6::20190522', '99C121::20190603', '86431A::20190528', '890A32::20190522', '890A12::20190603'}
# 2022-10-17 14:41:46.116 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 146: discarded duplicated and invalid CHOP entries after validation {'948X41::20190620', '890A32::20190603', '99B712::20190604', '99C128::20190606', '252X44:L:20190604'}
# 2022-10-17 14:41:46.116 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 147: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.117 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 148: discarded duplicated and invalid CHOP entries after validation {'186X20:L:20191028', '890A12::20191031', '186X10:L:20191028'}
# 2022-10-17 14:41:46.117 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 149: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.118 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 150: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.119 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 151: discarded duplicated and invalid CHOP entries after validation {'99B713::20190927', '948X41::20191011', '99B812::20191001'}
# 2022-10-17 14:41:46.119 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 152: discarded duplicated and invalid CHOP entries after validation {''}
# 2022-10-17 14:41:46.120 | DEBUG    | src.utils.dataframe_utils:_validate_chop_codes:94 - row 153: discarded duplicated and invalid CHOP entries after validation {'874199::20190913', '99C124::20191001', '009A14:L:20190912', '99B713::20190912', '99B813::20190912', '8688J3::20190916', '948X41::20191003'}
# 2022-10-17 14:41:46.130 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 2, primary diagnosis was changed from R11 to M8088
# 2022-10-17 14:41:46.132 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 20, primary diagnosis was changed from M340 to I730
# 2022-10-17 14:41:46.135 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 56, primary diagnosis was changed from A418 to A419
# 2022-10-17 14:41:46.137 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 88, primary diagnosis was changed from I5013 to I5001
# 2022-10-17 14:41:46.138 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 90, primary diagnosis was changed from I64 to I633
# 2022-10-17 14:41:46.139 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 91, primary diagnosis was changed from C180 to I7024
# 2022-10-17 14:41:46.139 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 99, primary diagnosis was changed from R55 to E871
# 2022-10-17 14:41:46.141 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 106, primary diagnosis was changed from C098 to C108
# 2022-10-17 14:41:46.142 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 115, primary diagnosis was changed from N185 to T814
# 2022-10-17 14:41:46.142 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 122, primary diagnosis was changed from S199 to S120
# 2022-10-17 14:41:46.143 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 127, primary diagnosis was changed from N10 to A498
# 2022-10-17 14:41:46.144 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 129, primary diagnosis was changed from N390 to A4151
# 2022-10-17 14:41:46.144 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 132, primary diagnosis was changed from J101 to J09
# 2022-10-17 14:41:46.145 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 134, primary diagnosis was changed from S3311 to S3201
# 2022-10-17 14:41:46.146 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 141, primary diagnosis was changed from F4540 to C341
# 2022-10-17 14:41:46.147 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 143, primary diagnosis was changed from I1001 to R522
# 2022-10-17 14:41:46.147 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 144, primary diagnosis was changed from C61 to A410
# 2022-10-17 14:41:46.148 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 149, primary diagnosis was changed from S3618 to C23
# 2022-10-17 14:41:46.149 | DEBUG    | src.utils.dataframe_utils:_validate_pd_revised_sd:130 - in row 150, primary diagnosis was changed from T8902 to A490

# %%
df_revised_case_d2d
# Out:
#      case_id patient_id gender  age_years  duration_of_stay  pccl   drg  \
# 0    6130587   10709587      M         54                13     3  E06A
# 1    6171196    5863929      M         62                 5     3  D62C
# 2    6269659   10160906      W         74                36     3  G72C
# 3    6329461   10156863      W         79                 6     3  B68C
# 4    6143166   10424299      M         75                 5     3  E77E
# ..       ...        ...    ...        ...               ...   ...   ...
# 149  6373573    4958322      W         76                 4     2  H64B
# 150  6475384    7878907      M         64                 7     2  X60C
# 151  6413158   10274171      M         82                17     2  B20A
# 152  6351575    1422600      M         60                10     2  I66B
# 153  6395577   10813769      M         68                24     2  E36D
#
#     old_pd new_pd bfs_code           added_icds removed_icds added_chops  \
# 0    J4400  J4400     M200               [F058]           []          []
# 1     J068   J068     M800  [I8028, C770, C787]           []          []
# 2    M8088  M8088     M100                [R64]           []          []
# 3    G3531  G3531     M100               [R471]           []          []
# 4     J690   J690     M100                [E43]           []          []
# ..     ...    ...      ...                  ...          ...         ...
# 149    C23    C23     M200         [K650, C786]           []          []
# 150   A490   A490     M100  [B9590, B957, D508]           []          []
# 151   D352   D352     M200        [I6201, I653]           []          []
# 152   I730   I730     M100          [L97, B965]           []          []
# 153  J4480  J4480     M200         [J860, J982]           []          []
#
#     removed_chops
# 0              []
# 1              []
# 2              []
# 3              []
# 4              []
# ..            ...
# 149            []
# 150            []
# 151            []
# 152            []
# 153            []
#
# [154 rows x 14 columns]

# %% [markdown]
# # Match revised DtoD data with the bfs data from the database

# %%
# get the case_id from revised_case

revised_case_id = df_revised_case_d2d['case_id'].values
revised_case_id
# Out:
# array(['6130587', '6171196', '6269659', '6329461', '6143166', '6152953',
#        '6175818', '6163583', '6157051', '6109664', '6310073', '6149288',
#        '6382682', '6421210', '6451720', '6460422', '6444850', '6456868',
#        '6461763', '6498608', '6366617', '6450099', '6472113', '6472399',
#        '6504693', '6444835', '6485720', '6454834', '6479102', '6442843',
#        '6445779', '6505033', '6470578', '6490778', '6463477', '6475938',
#        '6477686', '6486979', '6487991', '6501005', '6494118', '6482752',
#        '6503090', '6458354', '6472143', '6481583', '6467504', '6504436',
#        '6430480', '6470888', '6506865', '6514678', '6516985', '6479305',
#        '6485912', '6445940', '6453860', '6456105', '6501187', '6445671',
#        '6495041', '6506260', '6506464', '6247973', '6513021', '6473552',
#        '6246743', '6129004', '6160852', '6132798', '6159087', '6139918',
#        '6238727', '6281216', '6166492', '6253658', '6423485', '6143914',
#        '6156358', '6414478', '6438206', '6169777', '6470185', '6244807',
#        '6496212', '6373512', '6185615', '6226383', '6360396', '6292364',
#        '6411701', '6447339', '6327237', '6378377', '6343073', '6400797',
#        '6413014', '6323020', '6325880', '6392994', '6235924', '6389723',
#        '6368113', '6290255', '6236909', '6149389', '6131865', '6244881',
#        '6249549', '6254689', '6203737', '6269634', '6256463', '6247207',
#        '6295465', '6303078', '6303905', '6392382', '6267949', '6346871',
#        '6480276', '6386394', '6130321', '6341567', '6394409', '6395888',
#        '6408016', '6420458', '6453672', '6506254', '6216821', '6273418',
#        '6172978', '6205427', '6135736', '6300361', '6441232', '6294287',
#        '6377540', '6306620', '6324560', '6288636', '6293983', '6303398',
#        '6261877', '6280581', '6292141', '6368422', '6449048', '6373573',
#        '6475384', '6413158', '6351575', '6395577'], dtype=object)

# %%
revised_case_id_stripped = [case_id.lstrip('0') for case_id in revised_case_id]

# %%
# change the case_id the same format as bfs data e.g. '0041194601' 
# revised_case_id_pad0 = [case_id.zfill(10) for case_id in revised_case_id]
# revised_case_id_pad0[0]
# df_revised_case_d2d['case_id'] = revised_case_id_pad0

# %%
# match to the database
revised_case_db = bfs_db.get_bfs_cases_by_ids_no_pad0(revised_case_id_stripped)
revised_case_db.head()
# Out:
# Empty DataFrame
# Columns: [drg_cost_weight, aimedic_id, hospital_id, case_id, patient_id, age_years, age_days, gender, duration_of_stay, clinic_id, ventilation_hours, admission_weight, gestation_age, admission_date, admission_type, discharge_date, discharge_type, drg, adrg, pccl]
# Index: []

# %%
# create a new column for case_id_stripped with '0' for joining to the revised cases
revised_case_db['case_id_stripped']=  revised_case_db['case_id'].apply(lambda x: x.lstrip('0')) 
revised_case_db.head()
# Out:
# Empty DataFrame
# Columns: [drg_cost_weight, aimedic_id, hospital_id, case_id, patient_id, age_years, age_days, gender, duration_of_stay, clinic_id, ventilation_hours, admission_weight, gestation_age, admission_date, admission_type, discharge_date, discharge_type, drg, adrg, pccl, case_id_stripped]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_revised_case_d2d['case_id_stripped']=  df_revised_case_d2d['case_id'].apply(lambda x: x.lstrip('0')) 
df_revised_case_d2d.head()
# Out:
#    case_id patient_id gender  age_years  duration_of_stay  pccl   drg old_pd  \
# 0  6130587   10709587      M         54                13     3  E06A  J4400
# 1  6171196    5863929      M         62                 5     3  D62C   J068
# 2  6269659   10160906      W         74                36     3  G72C  M8088
# 3  6329461   10156863      W         79                 6     3  B68C  G3531
# 4  6143166   10424299      M         75                 5     3  E77E   J690
#
#   new_pd bfs_code           added_icds removed_icds added_chops removed_chops  \
# 0  J4400     M200               [F058]           []          []            []
# 1   J068     M800  [I8028, C770, C787]           []          []            []
# 2  M8088     M100                [R64]           []          []            []
# 3  G3531     M100               [R471]           []          []            []
# 4   J690     M100                [E43]           []          []            []
#
#   case_id_stripped
# 0          6130587
# 1          6171196
# 2          6269659
# 3          6329461
# 4          6143166

# %% [markdown]
# # Forming the normalized dataframe: Merge the selected revised case data with the matched from bfs data
#   If there are multiple cases were found based on case_id, patient_id will be used to match once more

# %%
# Check if there are multiple cases were found based on case_id, patient_id will be used to match once more
if revised_case_db.shape[0] <= len(revised_case_id):
    revised_case_d2d_subset = df_revised_case_d2d[COL_SUBSET_FROM_REVISED_CASES + ['patient_id 	']]
    revised_case_normalized = revised_case_d2d_subset.merge(revised_case_db, how ='inner', on=['patient_id 	'])
    num_match_case_id = revised_case_normalized.shape[0]
else:
    revised_case_d2d_subset = df_revised_case_d2d[COL_SUBSET_FROM_REVISED_CASES + ['patient_id']]
    revised_case_normalized = revised_case_d2d_subset.merge(revised_case_db, how ='inner', on=['patient_id 	'])
    num_match_case_patient_id = revised_case_normalized.shape[0]
print(revised_case_normalized.shape)
revised_case_normalized.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [11], line 3
#       1 # Check if there are multiple cases were found based on case_id, patient_id will be used to match once more
#       2 if revised_case_db.shape[0] <= len(revised_case_id):
# ----> 3     revised_case_d2d_subset = df_revised_case_d2d[COL_SUBSET_FROM_REVISED_CASES + ['patient_id 	']]
#       4     revised_case_normalized = revised_case_d2d_subset.merge(revised_case_db, how ='inner', on=['patient_id 	'])
#       5     num_match_case_id = revised_case_normalized.shape[0]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['patient_id \\t'] not in index"

# %%
df_revised_case_normalized = revised_case_normalized[COLS_TO_SELECT]
df_revised_case_normalized.head()

# %% [markdown]
# # Export the normalized revised cases with the neccessary columns to a csv file

# %%
hospital = file_info.hospital_name_db.replace(' ', '_') # replace spaces with '_' for the file name
hospital_year = f'{hospital}_{file_info.year}'

output_folder = os.path.join(ROOT_DIR, 'normalized_revision_data/')

if not os.path.exists(output_folder):
    os.mkdir(output_folder)

output_path = os.path.join(ROOT_DIR, 'normalized_revision_data/') + hospital_year + '.csv'

df_revised_case_normalized.to_csv(output_path)

# %% [markdown]
# # Report
#
# A small summary of:
# - how many cases could be matched in the DB, and based on which columns
# - how many cases were “correctly” revised, in terms of upcoding (still need to do after the `grouper` is available for python)

# %%
if revised_case_db.shape[0] <= len(revised_case_id):
    print(f'Based on the columns "case_id", "gender, "age_years", "duration_of_stay", "pccl", "drg", there are {num_match_case_id} out of {len(revised_case_id)} revised cases from DtoD that can be matched with the bfs database data for {file_info.hospital_name_db} {file_info.year}' )
else:
    print(f'Based on the columns "case_id" and "Patient_id", "gender, "age_years", "duration_of_stay", "pccl", "drg", there are {num_match_case_patient_id} out of {len(revised_case_id)} revised cases from DtoD that can be matched with the bfs database data for {file_info.hospital_name_db} {file_info.year}' )

# %%
print('All the normalized revised cases are exported to here: {}'.format(output_path))
