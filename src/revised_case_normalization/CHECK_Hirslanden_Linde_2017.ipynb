# %% [markdown]
# # Revised case normalization for Hirslanden Linde 2017
#
# Notes:
#
# - 17 of 17 revised DtoD cases were joined with the BFS cases from the DB.

# %%
import sys
sys.path.insert(0, '/home/jovyan/work')

from src.revised_case_normalization.notebook_functions.global_configs import *
from src.revised_case_normalization.notebook_functions.normalize import normalize
from src.revised_case_normalization.notebook_functions.revise import revise
from src.revised_case_normalization.notebook_functions.group import group, format_for_grouper_one_case, format_for_grouper
from src.revised_case_normalization.notebook_functions.update_db import update_db

# %%
file_info = FileInfo(os.path.join(ROOT_DIR, 'raw_data/HI-Bern_Salem_Beau Site_Linde.xlsx'),
                     'Hirslanden Linde', '2017', 'Änderungen_LI_2017')

print(file_info)
# Out:
# FileInfo(path='/home/jovyan/work/src/revised_case_normalization/raw_data/HI-Bern_Salem_Beau Site_Linde.xlsx', hospital_name_db='Hirslanden Linde', year='2017', sheet='Änderungen_LI_2017')

# %%
revised_cases_df = normalize(file_info)
revised_cases_df
# Out:
# 2022-11-10 10:49:20.479 | INFO     | src.revised_case_normalization.notebook_functions.normalize:normalize:35 - Read 18 cases for Hirslanden Linde 2017
# 2022-11-10 10:49:20.482 | INFO     | src.revised_case_normalization.notebook_functions.normalize:normalize:59 - TYPES:
# datum                     string
# tranche                   string
# case_id                   object
# patient_id                object
# gender                    string
# age_years                  int64
# bfs_code                  string
# duration_of_stay           int64
# pflegetage neu            string
# pccl                       int64
# pccl neu                  string
# old_pd                    string
# primary_diagnosis         string
# added_icds                string
# removed_icds              string
# added_chops               string
# removed_chops             string
# drg                       string
# drg neu                   string
# cw alt                    string
# cw neu                    string
# cw-änderung möglich       string
# cw-änderung akzeptiert    string
# unnamed: 23               string
# kommentar dtod            string
# kommentar li              string
# ablehnung arzt/ kasse     string
# case_id_norm              object
# dtype: object
# 2022-11-10 10:49:20.489 | INFO     | src.utils.dataframe_utils:validate_icd_codes:68 - Validated ICD codes in 'added_icds' and stored them into 'added_icds': All rows contain valid codes
# 2022-11-10 10:49:20.491 | INFO     | src.utils.dataframe_utils:validate_icd_codes:68 - Validated ICD codes in 'removed_icds' and stored them into 'removed_icds': All rows contain valid codes
# 2022-11-10 10:49:20.494 | INFO     | src.utils.dataframe_utils:validate_chop_codes:106 - Validated CHOP codes in 'added_chops' and stored them into 'added_chops': All rows contain valid codes
# 2022-11-10 10:49:20.496 | INFO     | src.utils.dataframe_utils:validate_chop_codes:106 - Validated CHOP codes in 'removed_chops' and stored them into 'removed_chops': All rows contain valid codes
# 2022-11-10 10:49:20.497 | INFO     | src.utils.dataframe_utils:remove_duplicated_chops:32 - Removing duplicated CHOP codes due to different casing ...
# 2022-11-10 10:49:20.501 | INFO     | src.utils.dataframe_utils:validate_pd_revised_sd:161 - Validated redundant PD info in 'added_icds'/'removed_icds': The following 1 rows were affected:
# row 0: primary diagnosis K430 => M6208
# 2022-11-10 10:49:20.504 | SUCCESS  | src.revised_case_normalization.notebook_functions.normalize:normalize:106 - Completed validation
#    case_id        patient_id gender  age_years  duration_of_stay case_id_norm old_pd primary_diagnosis bfs_code  pccl   drg          added_icds removed_icds added_chops removed_chops
# 0   657093  D594EE66C57B286C      W         72                11       657093   K430             M6208     M200     3  G08B                  []           []          []            []
# 1   669177  8125714B0579B1A0      M         63                 8       669177   J181              J181     M100     2  E77G       [R650, J9610]           []          []            []
# 2   670466  6A0E65CA7E381F17      W         76                24       670466   C187              C187     M200     3  G02C              [R650]           []          []            []
# 3   674893  E120201DBEFFB939      M         73                 6       674893  M4802             M4802     M200     2  I09E              [T810]           []          []            []
# 4   680781  F5130C1F2D9962C3      M         72                 4       680781   N328              N328     M200     3  L18B             [G2090]           []          []            []
# 5   681347  245EC023C64BCAE9      W         73                11       681347   M511              M511     M200     3  I10C              [I422]           []          []            []
# 6   663181  89435BFF1A8C7B75      W         81                12       663181   M161              M161     M200     3  I46C       [E1140, G632]      [E1190]          []            []
# 7   677195  D0CE1E822E9B314C      M         88                12       677195  I5013             I5013     M100     3  F62C             [J9600]           []          []            []
# 8   696484  2201A24926281FA3      M         72                 5       696484   D410              D410     M100     3  L62C              [F339]           []          []            []
# 9   664975  4151972F3AAB5BC7      M         60                11       664975  I5001             I5001     M100     3  F62C              [I691]           []          []            []
# 10  672144  4298B471D528C134      W         88                 9       672144   J181              J181     M100     3  E77F              [D508]           []          []            []
# 11  680512  2889E45442195FD9      M         75                 2       680512   N390              N390     M100     2  L63E              [A099]           []          []            []
# 12  685780  026B94F08EA3285F      W         75                 7       685780   N390              N390     M100     3  L63D  [N183, A099, D862]           []          []            []
# 13  686863  E5CBBACEC763898F      W         78                 9       686863   T827              T827     M100     3  F75C              [A099]           []          []            []
# 14  687808  00A330D2F43888E6      M         69                 5       687808   M500              M500     M200     2  I09E              [F101]           []          []            []
# 15  693112  E7FFCF27A5A3A38B      W         54                 8       693112   C509              C509     M100     3  J62B               [R64]           []          []            []
# 16  697356  9B102B0509713C7D      W         84                 9       697356   J181              J181     M100     3  E77F             [I1100]      [I1000]          []            []
# 17  703038  0A210188E413D41B      M         64                 9       703038   C155              C155     M100     3  G60B             [L8914]           []          []            []

# %% [markdown]
# # Match revised DtoD data with the BfS data from the database

# %%
cols_to_join = list(VALIDATION_COLS)
cols_to_join.remove(CASE_ID_COL)
cols_to_join.append(NORM_CASE_ID_COL)
# Ignore the patient ID in this dataset, because it is encrypted
cols_to_join.remove(PATIENT_ID_COL)

revised_cases, unmatched = revise(file_info, revised_cases_df, validation_cols=cols_to_join)
revised_cases.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 7
#       4 # Ignore the patient ID in this dataset, because it is encrypted
#       5 cols_to_join.remove(PATIENT_ID_COL)
# ----> 7 revised_cases, unmatched = revise(file_info, revised_cases_df, validation_cols=cols_to_join)
#       8 revised_cases.head()
#
# File <@beartype(src.revised_case_normalization.notebook_functions.revise.revise) at 0xffff60e440d0>:75, in revise(__beartype_func, __beartype_get_violation, __beartype_object_187651188152544, __beartype_object_187651197181088, __beartype_getrandbits, *args, **kwargs)
#
# File ~/work/src/revised_case_normalization/notebook_functions/revise.py:31, in revise(file_info, revised_cases_df, validation_cols)
#      19 """Match revised cases with Database and return revised cases with aimedic_id and other columns of interests after matching.
#      20
#      21 @param file_info: An instance of FileInfo, which contains the name and path of filename, hospital name and year and
#    (...)
#      26
#      27 """
#      29 with Database() as db:
#      30     # Read the sociodemographics from the DB, and normalize the case ID by removing leading zeros
# ---> 31     cases_in_db = get_sociodemographics_for_hospital_year(file_info.hospital_name_db, int(file_info.year), db.session)
#      32     cases_in_db[NORM_CASE_ID_COL] = cases_in_db[CASE_ID_COL].apply(remove_leading_zeros)
#      34     # Merge cases in DB with the revised cases
#
# File <@beartype(src.service.bfs_cases_db_service.get_sociodemographics_for_hospital_year) at 0xffff605335b0>:67, in get_sociodemographics_for_hospital_year(__beartype_func, __beartype_get_violation, __beartype_object_187651202482832, __beartype_object_187651197181088, *args, **kwargs)
#
# File ~/work/src/service/bfs_cases_db_service.py:88, in get_sociodemographics_for_hospital_year(hospital_name, year, session)
#      86 num_cases_in_db = df.shape[0]
#      87 if num_cases_in_db == 0:
# ---> 88     raise ValueError(f"There is no data for the hospital '{hospital_name}' in {year}")
#      89 else:
#      90     logger.info(f"Read {num_cases_in_db} rows from the DB, for the hospital '{hospital_name}' in {year}")
#
# ValueError: There is no data for the hospital 'Hirslanden Linde' in 2017

# %%
if unmatched.shape[0] > 0:
    unmatched

# %%
revised_cases.loc[106]

# %%
revisions_update, diagnoses_update, procedures_update = group(revised_cases)
revisions_update[REVISION_DATE_COL] = '2022-12-31'

# %%
procedures_update

# %%
revisions_update

# %%
update_db(revisions_update, diagnoses_update, procedures_update)
